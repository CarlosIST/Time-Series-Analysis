# %% [markdown]
# # Multivariate Time Series
#
# #### By Carlos Santillán
#
# #### December 28, 2021

# %% [markdown]
# ## Load Data

# %%
# !pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 63 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 6.4 MB 18.9 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
import numpy as np                 ### Vectores
import pandas as pd                ### DataFrames
import matplotlib.pyplot as plt    ### Gráficos
import datetime
import yfinance as yf

# %%
data_blk = yf.download('BLK')   ### BlackRock
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_eth = yf.download('ETH-USD')    ### Ethereum
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_luna = yf.download('LUNA1-USD') ### Luna
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_btc = yf.download('BTC-USD') ### Bitcoin
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_spy = yf.download('SPY') ### SP500
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_vti = yf.download('VTI') ### Vanguard
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_nvo = yf.download('NVO') ### NovoNordisk
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_gold_price = yf.download('XAUUSD=X') ### Gold Price
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_gold = yf.download('GLD') ### Gold Price
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_oil = yf.download('CL=F') ### Crude Oil
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_lit = yf.download('LIT') ### Lithium ETF
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_water = yf.download('CGW') ### Water ETF
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_glencore = yf.download('GLEN.L') ### Largest Oil & Gas miner
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_ag = yf.download('DBA') ### Agriculture ETF
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_ews = yf.download('EWS') ### Singapore ETF
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_ewc = yf.download('EWC') ### Canada ETF
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_zec = yf.download('ZEC-USD') ### ZCASH Cryptocurrency
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_blk.head()
# Out:
#               Open    High      Low   Close  Adj Close   Volume
# Date
# 1999-10-01  14.000  14.250  14.0000  14.125   9.345778  3162400
# 1999-10-04  14.125  14.125  14.0000  14.000   9.263077   533400
# 1999-10-05  14.000  14.125  14.0000  14.125   9.345778   270600
# 1999-10-06  14.125  14.875  14.1250  14.875   9.842017   205400
# 1999-10-07  14.875  14.875  14.0625  14.125   9.345778   214200

# %%
data_blk['Adj Close'].plot(figsize=(15, 5))
plt.title("Data BlackRock")
# Out:
# Text(0.5, 1.0, 'Data BlackRock')

# %%
data_water['Adj Close'].plot(figsize=(15, 5))
plt.title("Data Water ETF")
# Out:
# Text(0.5, 1.0, 'Data Water ETF')

# %%
## pandas.Dataframe.shift(# lags)
## Using shift(1), we can get the row just above the present row. Here, # lags is 1.
## log() is a function given in numpy package in python. It calculates the natural log of the value given inside it.
#data_blk['Log Return'] = np.log(PG['Adj Close']/PG['Adj Close'].shift(1))

def calculate_returns (dataframe, ticker):
  dataframe['LOG_RETURN_'+ticker] = np.log(dataframe['Adj Close'] / dataframe['Adj Close'].shift(1))
  return

# %%
calculate_returns(data_blk, 'BLK')
calculate_returns(data_ag, 'DBA')
calculate_returns(data_btc, 'BTC')
calculate_returns(data_eth, 'ETH')
calculate_returns(data_ewc, 'EWC')
calculate_returns(data_ews, 'EWS')
calculate_returns(data_glencore, 'GLEN')
calculate_returns(data_gold, 'GLD')
calculate_returns(data_gold_price, 'GLD_PRICE')
calculate_returns(data_lit, 'LIT')
calculate_returns(data_luna, 'LUNA')
calculate_returns(data_nvo, 'NVO')
calculate_returns(data_oil, 'OIL')
calculate_returns(data_vti, 'VTI')
calculate_returns(data_water, 'CGW')
calculate_returns(data_spy, 'SP500')
calculate_returns(data_zec, 'ZEC')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
data_lit.head()
# Out:
#                  Open       High        Low  ...  Adj Close  Volume  LOG_RETURN_LIT
# Date                                         ...
# 2010-07-23  31.500000  32.220001  31.360001  ...  27.418844  232100             NaN
# 2010-07-26  32.599998  33.000000  32.200001  ...  28.049355   82700        0.022735
# 2010-07-27  33.500000  33.500000  32.639999  ...  27.930067   87100       -0.004262
# 2010-07-28  33.000000  33.000000  32.400002  ...  27.827822  152650       -0.003667
# 2010-07-29  33.500000  33.860001  33.139999  ...  28.662828  125400        0.029565
#
# [5 rows x 7 columns]

# %%
data_blk.tail()
# Out:
#                   Open        High  ...   Volume  LOG_RETURN_BLK
# Date                                ...
# 2022-01-31  805.210022  823.669983  ...   611200        0.018148
# 2022-02-01  827.909973  831.320007  ...   631900        0.003651
# 2022-02-02  830.049988  830.159973  ...  1030400       -0.004174
# 2022-02-03  816.500000  823.729980  ...   582600       -0.020562
# 2022-02-04  802.000000  817.440002  ...   667400        0.005014
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Rename Adj Close Column

# %%
def rename_close(dataframe, ticker):
  '''
  DESC.: Function that takes a dataframe and a ticker and renames the existing
          Adj Close column to CLOSE_ticker
  INPUT: dataframe (pandas, from yfinance)
  INPUT: ticker (str)
  OUTPUT: dataframe with renamed column
  '''
  dataframe.rename(columns={'Adj Close': 'CLOSE_'+ticker}, inplace = True)
  return

# %%
rename_close(data_blk, 'BLK')

# %%
rename_close(data_ag, 'DBA')
rename_close(data_btc, 'BTC')
rename_close(data_eth, 'ETH')
rename_close(data_ewc, 'EWC')
rename_close(data_ews, 'EWS')
rename_close(data_glencore, 'GLEN')
rename_close(data_gold, 'GLD')
rename_close(data_gold_price, 'GLD_PRICE')
rename_close(data_lit, 'LIT')
rename_close(data_luna, 'LUNA')
rename_close(data_nvo, 'NVO')
rename_close(data_oil, 'OIL')
rename_close(data_vti, 'VTI')
rename_close(data_water, 'CGW')
rename_close(data_spy, 'SP500')
rename_close(data_zec, 'ZEC')

# %% [markdown]
# ### Trim data for specific number of years

# %%
def trim_series(dataframe, num_of_years):
  '''
  DESC.: Function that takes a dataframe an a specified number of years and
          trims the dataset in order to have the desired number of rows.
  INPUT: dataframe (pandas, from yfinance)
  INPUT: num_of_years (float)
  OUTPUT: trimmed dataframe
  '''
  dataframe_trim = dataframe.iloc[-round(num_of_years * 365):]
  return dataframe_trim

# %%
data_blk_trim = trim_series(data_blk, 2.5)
data_ag_trim =trim_series(data_ag, 2.5)
data_btc_trim =trim_series(data_btc, 2.5)
data_eth_trim =trim_series(data_eth, 2.5)
data_ewc_trim =trim_series(data_ewc, 2.5)
data_ews_trim =trim_series(data_ews, 2.5)
data_glencore_trim =trim_series(data_glencore, 2.5)
data_gold_trim =trim_series(data_gold, 2.5)
data_gold_price_trim =trim_series(data_gold_price, 2.5)
data_lit_trim =trim_series(data_lit, 2.5)
data_luna_trim =trim_series(data_luna, 2.5)
data_nvo_trim =trim_series(data_nvo, 2.5)
data_oil_trim =trim_series(data_oil, 2.5)
data_vti_trim =trim_series(data_vti, 2.5)
data_water_trim =trim_series(data_water, 2.5)
data_spy_trim =trim_series(data_spy, 2.5)
data_zec_trim =trim_series(data_zec, 2.5)

# %%
len(data_spy_trim)
# Out:
# 912

# %%
data_water_trim
# Out:
#                  Open       High        Low  ...  CLOSE_CGW  Volume  LOG_RETURN_CGW
# Date                                         ...
# 2018-06-25  33.430000  33.580002  33.340000  ...  31.340050   31400       -0.000298
# 2018-06-26  33.529999  33.660000  33.509998  ...  31.340050  109900        0.000000
# 2018-06-27  33.480000  33.689999  33.240002  ...  31.087536   53700       -0.008090
# 2018-06-28  33.169998  33.330002  33.119999  ...  31.096886   52400        0.000301
# 2018-06-29  33.410000  33.639999  33.410000  ...  31.321346   28300        0.007192
# ...               ...        ...        ...  ...        ...     ...             ...
# 2022-01-31  52.790001  54.029999  52.790001  ...  53.990002   53000        0.023804
# 2022-02-01  54.330002  54.509998  53.720001  ...  54.139999  226000        0.002774
# 2022-02-02  54.410000  54.560001  54.150002  ...  54.419998   51000        0.005158
# 2022-02-03  53.810001  53.919998  53.130001  ...  53.189999   50700       -0.022861
# ...

# %% [markdown]
# ### Create datasets with all assets

# %%
data_close_general = pd.concat([data_blk_trim['CLOSE_BLK'], data_ag_trim['CLOSE_DBA'], data_btc_trim['CLOSE_BTC'], 
                                data_eth_trim['CLOSE_ETH'], data_ewc_trim['CLOSE_EWC'], data_ews_trim['CLOSE_EWS'], 
                                data_glencore_trim['CLOSE_GLEN'], data_gold_trim['CLOSE_GLD'], data_gold_price_trim['CLOSE_GLD_PRICE'], 
                                data_lit_trim['CLOSE_LIT'], data_luna_trim['CLOSE_LUNA'], data_nvo_trim['CLOSE_NVO'], 
                                data_oil_trim['CLOSE_OIL'], data_vti_trim['CLOSE_VTI'], data_water_trim['CLOSE_CGW'], 
                                data_spy_trim['CLOSE_SP500'], data_zec_trim['CLOSE_ZEC']],
                               axis = 1)

# %%
data_log_returns_general = pd.concat([data_blk_trim['LOG_RETURN_BLK'], data_ag_trim['LOG_RETURN_DBA'], data_btc_trim['LOG_RETURN_BTC'], 
                                data_eth_trim['LOG_RETURN_ETH'], data_ewc_trim['LOG_RETURN_EWC'], data_ews_trim['LOG_RETURN_EWS'], 
                                data_glencore_trim['LOG_RETURN_GLEN'], data_gold_trim['LOG_RETURN_GLD'], data_gold_price_trim['LOG_RETURN_GLD_PRICE'], 
                                data_lit_trim['LOG_RETURN_LIT'], data_luna_trim['LOG_RETURN_LUNA'], data_nvo_trim['LOG_RETURN_NVO'], 
                                data_oil_trim['LOG_RETURN_OIL'], data_vti_trim['LOG_RETURN_VTI'], data_water_trim['LOG_RETURN_CGW'], 
                                data_spy_trim['LOG_RETURN_SP500'], data_zec_trim['LOG_RETURN_ZEC']],
                               axis = 1)

# %%
data_close_equity = pd.concat([data_blk_trim['CLOSE_BLK'], data_ag_trim['CLOSE_DBA'],  
                               data_ewc_trim['CLOSE_EWC'], data_ews_trim['CLOSE_EWS'], 
                                data_glencore_trim['CLOSE_GLEN'], data_gold_trim['CLOSE_GLD'], 
                                data_lit_trim['CLOSE_LIT'], data_nvo_trim['CLOSE_NVO'], 
                                data_oil_trim['CLOSE_OIL'], data_vti_trim['CLOSE_VTI'], data_water_trim['CLOSE_CGW'], 
                                data_spy_trim['CLOSE_SP500']],
                               axis = 1)

# %%
data_log_returns_equity = pd.concat([data_blk_trim['LOG_RETURN_BLK'], data_ag_trim['LOG_RETURN_DBA'],  
                               data_ewc_trim['LOG_RETURN_EWC'], data_ews_trim['LOG_RETURN_EWS'], 
                                data_glencore_trim['LOG_RETURN_GLEN'], data_gold_trim['LOG_RETURN_GLD'], 
                                data_lit_trim['LOG_RETURN_LIT'], data_nvo_trim['LOG_RETURN_NVO'], 
                                data_oil_trim['LOG_RETURN_OIL'], data_vti_trim['LOG_RETURN_VTI'], data_water_trim['LOG_RETURN_CGW'], 
                                data_spy_trim['LOG_RETURN_SP500']],
                               axis = 1)

# %%
data_close_crypto = pd.concat([data_btc_trim['CLOSE_BTC'], data_eth_trim['CLOSE_ETH'],
                               data_luna_trim['CLOSE_LUNA'], data_zec_trim['CLOSE_ZEC']],
                               axis = 1)

# %%
data_log_returns_crypto = pd.concat([data_btc_trim['LOG_RETURN_BTC'], data_eth_trim['LOG_RETURN_ETH'],
                               data_luna_trim['LOG_RETURN_LUNA'], data_zec_trim['LOG_RETURN_ZEC']],
                               axis = 1)

# %%
data_close_select = pd.concat([data_blk_trim['CLOSE_BLK'], data_ag_trim['CLOSE_DBA'], data_btc_trim['CLOSE_BTC'], 
                                data_eth_trim['CLOSE_ETH'], data_ews_trim['CLOSE_EWS'], 
                                data_gold_trim['CLOSE_GLD'], data_lit_trim['CLOSE_LIT'], data_luna_trim['CLOSE_LUNA'],
                                data_nvo_trim['CLOSE_NVO'], 
                                data_oil_trim['CLOSE_OIL'], data_vti_trim['CLOSE_VTI'], data_water_trim['CLOSE_CGW'], 
                                data_zec_trim['CLOSE_ZEC']],
                               axis = 1)

# %%
data_log_returns_select = pd.concat([data_blk_trim['LOG_RETURN_BLK'], data_ag_trim['LOG_RETURN_DBA'], data_btc_trim['LOG_RETURN_BTC'], 
                                data_eth_trim['LOG_RETURN_ETH'], data_ews_trim['LOG_RETURN_EWS'], 
                                data_gold_trim['LOG_RETURN_GLD'], data_lit_trim['LOG_RETURN_LIT'], data_luna_trim['LOG_RETURN_LUNA'],
                                data_nvo_trim['LOG_RETURN_NVO'], 
                                data_oil_trim['LOG_RETURN_OIL'], data_vti_trim['LOG_RETURN_VTI'], data_water_trim['LOG_RETURN_CGW'], 
                                data_zec_trim['LOG_RETURN_ZEC']],
                               axis = 1)

# %%
data_log_returns_select
# Out:
#             LOG_RETURN_BLK  LOG_RETURN_DBA  ...  LOG_RETURN_CGW  LOG_RETURN_ZEC
# Date                                        ...
# 2018-06-25       -0.014646       -0.016053  ...       -0.000298             NaN
# 2018-06-26       -0.008363       -0.001676  ...        0.000000             NaN
# 2018-06-27       -0.014433       -0.007293  ...       -0.008090             NaN
# 2018-06-28       -0.003501        0.000563  ...        0.000301             NaN
# 2018-06-29       -0.005456        0.014525  ...        0.007192             NaN
# ...                    ...             ...  ...             ...             ...
# 2022-02-02       -0.004174       -0.002446  ...        0.005158       -0.005724
# 2022-02-03       -0.020562        0.001468  ...       -0.022861        0.017480
# 2022-02-04        0.005014        0.006823  ...       -0.007549        0.067871
# 2022-02-05             NaN             NaN  ...             NaN        0.080261
# ...

# %%
data_close_select
# Out:
#              CLOSE_BLK  CLOSE_DBA  ...  CLOSE_CGW   CLOSE_ZEC
# Date                               ...
# 2018-06-25  471.268860  17.456091  ...  31.340050         NaN
# 2018-06-26  467.344238  17.426867  ...  31.340050         NaN
# 2018-06-27  460.647583  17.300234  ...  31.087536         NaN
# 2018-06-28  459.037476  17.309975  ...  31.096886         NaN
# 2018-06-29  456.539948  17.563244  ...  31.321346         NaN
# ...                ...        ...  ...        ...         ...
# 2022-02-02  822.510010  20.420000  ...  54.419998   98.352333
# 2022-02-03  805.770020  20.450001  ...  53.189999  100.086617
# 2022-02-04  809.820007  20.590000  ...  52.790001  107.115463
# 2022-02-05         NaN        NaN  ...        NaN  116.067101
# 2022-02-06         NaN        NaN  ...        NaN  123.676186
#
# [1196 rows x 13 columns]

# %% [markdown]
# ### Handling Missing data

# %% [markdown]
# Since the missing data comes from holidays and weekends in the equity data, it is prudent to fill it out using either forward or backward fill (easiest way)

# %% [markdown]
# Another option would be using linear interpolation, and a final but most difficult one is using a Bayesian Prior on the missing data.

# %%
from scipy.interpolate import interp1d
from sklearn.metrics import mean_squared_error

# %%
data_close_select_ffill = data_close_select.ffill()
data_close_select_ffill
# Out:
#              CLOSE_BLK  CLOSE_DBA  ...  CLOSE_CGW   CLOSE_ZEC
# Date                               ...
# 2018-06-25  471.268860  17.456091  ...  31.340050         NaN
# 2018-06-26  467.344238  17.426867  ...  31.340050         NaN
# 2018-06-27  460.647583  17.300234  ...  31.087536         NaN
# 2018-06-28  459.037476  17.309975  ...  31.096886         NaN
# 2018-06-29  456.539948  17.563244  ...  31.321346         NaN
# ...                ...        ...  ...        ...         ...
# 2022-02-02  822.510010  20.420000  ...  54.419998   98.352333
# 2022-02-03  805.770020  20.450001  ...  53.189999  100.086617
# 2022-02-04  809.820007  20.590000  ...  52.790001  107.115463
# 2022-02-05  809.820007  20.590000  ...  52.790001  116.067101
# 2022-02-06  809.820007  20.590000  ...  52.790001  123.676186
#
# [1196 rows x 13 columns]

# %%
data_log_returns_select_ffill = data_log_returns_select.ffill()
data_log_returns_select_ffill
# Out:
#             LOG_RETURN_BLK  LOG_RETURN_DBA  ...  LOG_RETURN_CGW  LOG_RETURN_ZEC
# Date                                        ...
# 2018-06-25       -0.014646       -0.016053  ...       -0.000298             NaN
# 2018-06-26       -0.008363       -0.001676  ...        0.000000             NaN
# 2018-06-27       -0.014433       -0.007293  ...       -0.008090             NaN
# 2018-06-28       -0.003501        0.000563  ...        0.000301             NaN
# 2018-06-29       -0.005456        0.014525  ...        0.007192             NaN
# ...                    ...             ...  ...             ...             ...
# 2022-02-02       -0.004174       -0.002446  ...        0.005158       -0.005724
# 2022-02-03       -0.020562        0.001468  ...       -0.022861        0.017480
# 2022-02-04        0.005014        0.006823  ...       -0.007549        0.067871
# 2022-02-05        0.005014        0.006823  ...       -0.007549        0.080261
# ...

# %%
print("Rows in BTC data: " + str(len(data_btc_trim)))
print("Rows in ETH data: " + str(len(data_eth_trim)))
print("Rows in LUNA data: " + str(len(data_luna_trim)))
print("Rows in ZEC data: " + str(len(data_zec_trim)))
# Out:
# Rows in BTC data: 912
# Rows in ETH data: 912
# Rows in LUNA data: 912
# Rows in ZEC data: 912

# %% [markdown]
# Since our data with the least volume is the one from LUNA, we will keep only those records so that we don´t have missing values at the beginning of the series.

# %%
len(data_close_select_ffill)
# Out:
# 1196

# %%
len(data_log_returns_select_ffill)
# Out:
# 1196

# %%
data_close_select_ffill = data_close_select_ffill.iloc[-(len(data_luna_trim)-1):]
data_log_returns_select_ffill = data_log_returns_select_ffill.iloc[-(len(data_luna_trim)-1):]

# %%
data_close_select_ffill
# Out:
#              CLOSE_BLK  CLOSE_DBA  ...  CLOSE_CGW   CLOSE_ZEC
# Date                               ...
# 2019-08-11  401.679596  15.506454  ...  35.166401   59.945904
# 2019-08-12  392.361450  14.994493  ...  35.042168   56.783203
# 2019-08-13  400.737396  14.945268  ...  35.328850   55.272392
# 2019-08-14  387.584625  14.974803  ...  34.478363   50.384266
# 2019-08-15  385.634277  14.896041  ...  34.793713   50.822243
# ...                ...        ...  ...        ...         ...
# 2022-02-02  822.510010  20.420000  ...  54.419998   98.352333
# 2022-02-03  805.770020  20.450001  ...  53.189999  100.086617
# 2022-02-04  809.820007  20.590000  ...  52.790001  107.115463
# 2022-02-05  809.820007  20.590000  ...  52.790001  116.067101
# 2022-02-06  809.820007  20.590000  ...  52.790001  123.676186
#
# [911 rows x 13 columns]

# %% [markdown]
# ## VAR Method

# %% [markdown]
# ### What is VAR?

# %% [markdown]
# First, what is Vector Autoregression (VAR) and when to use it? Vector Autoregression (VAR) is a multivariate forecasting algorithm that is used when two or more time series influence each other. That means, the basic requirements in order to use VAR are:
#
# 1. You need at least two time series (variables)
#
#
# 2. The time series should influence each other.
#
#
# So why is it called ‘Autoregressive’? It is considered as an Autoregressive model because, each variable (Time Series) is modeled as a function of the past values, that is the predictors are nothing but the lags (time delayed value) of the series. Ok, so how is VAR different from other Autoregressive models like AR, ARMA or ARIMA? The primary difference is those models are uni-directional, where, the predictors influence the Y and not vice-versa. Whereas, Vector Auto Regression (VAR) is bi-directional. That is, the variables influence each other.

# %% [markdown]
# ### Building a VAR Model in Python

# %% [markdown]
# The procedure to build a VAR model involves the following steps:
#
# 1. Analyze the time series characteristics
# 2. Test for causation amongst the time series
# 3. Test for stationarity
# 4. Transform the series to make it stationary, if needed
# 5. Find optimal order (p)
# 6. Prepare training and test datasets
# 7. Train the model
# 8. Roll back the transformations, if any.
# 9. Evaluate the model using test set
# 10. Forecast to future

# %% [markdown]
# #### Libraries for VAR

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Import Statsmodels
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# #### Visualize the time Series

# %%
data_close_select_ffill.shape
# Out:
# (911, 13)

# %%
fig, axes = plt.subplots(nrows=7, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = data_close_select_ffill[data_close_select_ffill.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(data_close_select_ffill.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-54-604612072eb4> in <module>()
#       1 fig, axes = plt.subplots(nrows=7, ncols=2, dpi=120, figsize=(10,6))
#       2 for i, ax in enumerate(axes.flatten()):
# ----> 3     data = data_close_select_ffill[data_close_select_ffill.columns[i]]
#       4     ax.plot(data, color='red', linewidth=1)
#       5     # Decorations
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4602         if is_scalar(key):
#    4603             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4604             return getitem(key)
#    4605
#    4606         if isinstance(key, slice):
#
# IndexError: index 13 is out of bounds for axis 0 with size 13

# %%
fig, axes = plt.subplots(nrows=7, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = data_log_returns_select_ffill[data_log_returns_select_ffill.columns[i]]
    ax.plot(data, color='blue', linewidth=1)
    # Decorations
    ax.set_title(data_log_returns_select_ffill.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-26518cab35d7> in <module>()
#       1 fig, axes = plt.subplots(nrows=7, ncols=2, dpi=120, figsize=(10,6))
#       2 for i, ax in enumerate(axes.flatten()):
# ----> 3     data = data_log_returns_select_ffill[data_log_returns_select_ffill.columns[i]]
#       4     ax.plot(data, color='blue', linewidth=1)
#       5     # Decorations
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4602         if is_scalar(key):
#    4603             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4604             return getitem(key)
#    4605
#    4606         if isinstance(key, slice):
#
# IndexError: index 13 is out of bounds for axis 0 with size 13

# %% [markdown]
# #### Testing Causation using Granger’s Causality Test

# %% [markdown]
# The basis behind Vector AutoRegression is that each of the time series in the system influences each other. That is, you can predict the series with past values of itself along with other series in the system. Using Granger’s Causality Test, it’s possible to test this relationship before even building the model.
#
# So what does Granger’s Causality really test? Granger’s causality tests the null hypothesis that the coefficients of past values in the regression equation is zero. In simpler terms, the past values of time series (X) do not cause the other series (Y).
#
# So, **if the p-value obtained from the test is lesser than the significance level of 0.05, then, you can safely reject the null hypothesis**. The below code implements the Granger’s Causality test for all possible combinations of the time series in a given dataframe and stores the p-values of each combination in the output matrix:

# %%
from statsmodels.tsa.stattools import grangercausalitytests
# maxlag=12
test = 'ssr_chi2test'

def grangers_causation_matrix(data, variables, maxlag, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

# %%
grangers_causation_matrix(data_close_select_ffill, variables = data_close_select_ffill.columns, maxlag = 20)
# Out:
#               CLOSE_BLK_x  CLOSE_DBA_x  ...  CLOSE_CGW_x  CLOSE_ZEC_x
# CLOSE_BLK_y        1.0000       0.5729  ...       0.0006       0.0279
# CLOSE_DBA_y        0.0130       1.0000  ...       0.0057       0.0010
# CLOSE_BTC_y        0.1240       0.0016  ...       0.3820       0.0000
# CLOSE_ETH_y        0.0009       0.0000  ...       0.0056       0.0000
# CLOSE_EWS_y        0.0041       0.0067  ...       0.0013       0.7791
# CLOSE_GLD_y        0.1423       0.1181  ...       0.0097       0.4206
# CLOSE_LIT_y        0.0037       0.0710  ...       0.0899       0.0024
# CLOSE_LUNA_y       0.0287       0.0211  ...       0.0109       0.0000
# CLOSE_NVO_y        0.0183       0.0519  ...       0.0069       0.2392
# CLOSE_OIL_y        0.0006       0.0000  ...       0.0000       0.1174
# CLOSE_VTI_y        0.0100       0.5227  ...       0.0745       0.2086
# CLOSE_CGW_y        0.0003       0.3246  ...       1.0000       0.2029
# ...

# %% [markdown]
# So how to read the above output?
#
# The row are the Response (Y) and the columns are the predictor series (X).
#
# For example, if you take the value 0.0003 in (row 1, column 2), it refers to the p-value of pgnp_x causing rgnp_y. Whereas, the 0.000 in (row 2, column 1) refers to the p-value of rgnp_y causing pgnp_x.
#
# So, how to interpret the p-values?
# **If a given p-value is < significance level (0.05), then, the corresponding X series (column) causes the Y (row)**.
#
# For example, P-Value of 0.0003 at (row 1, column 2) represents the p-value of the Grangers Causality test for pgnp_x causing rgnp_y, which is less that the significance level of 0.05. So, you can reject the null hypothesis and conclude pgnp_x causes rgnp_y. Looking at the P-Values in the above table, you can pretty much observe that all the variables (time series) in the system are interchangeably causing each other. This makes this system of multi time series a good candidate for using VAR models to forecast. Next, let’s do the Cointegration test.

# %%
grangers_causation_matrix(data_log_returns_select_ffill, variables = data_log_returns_select_ffill.columns, maxlag=20)
# Out:
#                    LOG_RETURN_BLK_x  ...  LOG_RETURN_ZEC_x
# LOG_RETURN_BLK_y             1.0000  ...            0.0004
# LOG_RETURN_DBA_y             0.0000  ...            0.0113
# LOG_RETURN_BTC_y             0.0056  ...            0.0129
# LOG_RETURN_ETH_y             0.0071  ...            0.1264
# LOG_RETURN_EWS_y             0.0000  ...            0.4241
# LOG_RETURN_GLD_y             0.0037  ...            0.0254
# LOG_RETURN_LIT_y             0.0000  ...            0.0050
# LOG_RETURN_LUNA_y            0.5768  ...            0.0147
# LOG_RETURN_NVO_y             0.0388  ...            0.0023
# LOG_RETURN_OIL_y             0.0000  ...            0.0022
# LOG_RETURN_VTI_y             0.0000  ...            0.0035
# LOG_RETURN_CGW_y             0.0000  ...            0.0031
# LOG_RETURN_ZEC_y             0.0264  ...            1.0000
#
# [13 rows x 13 columns]

# %% [markdown]
# #### Cointegration Test

# %% [markdown]
# Cointegration test helps to establish the presence of a statistically significant connection between two or more time series. But, what does Cointegration mean? To understand that, you first need to know what is ‘order of integration’ (d). Order of integration(d) is nothing but the number of differencing required to make a non-stationary time series stationary.
#
# Now, when you have two or more time series, and there exists a linear combination of them that has an order of integration (d) less than that of the individual series, then the collection of series is said to be cointegrated. Ok? When two or more time series are cointegrated, it means they have a long run, statistically significant relationship. This is the basic premise on which Vector Autoregression(VAR) models is based on.
#
# So, it’s fairly common to implement the cointegration test before starting to build VAR models. Alright, So how to do this test? Soren Johanssen in his paper (1991) devised a procedure to implement the cointegration test. It is fairly straightforward to implement in python’s statsmodels, as you can see below.

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

def cointegration_test(df, alpha=0.05): 
    """Perform Johanson's Cointegration Test and Report Summary"""
    out = coint_johansen(df,-1,5)
    d = {'0.90':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
    def adjust(val, length= 6): return str(val).ljust(length)

    # Summary
    print('Name   ::  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

# %%
cointegration_test(data_close_select_ffill)
# Out:
# Name   ::  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# CLOSE_BLK ::  380.72    > nan       =>   False
# CLOSE_DBA ::  297.3     > 311.1288  =>   False
# CLOSE_BTC ::  239.25    > 263.2603  =>   False
# CLOSE_ETH ::  186.91    > 219.4051  =>   False
# CLOSE_EWS ::  146.44    > 179.5199  =>   False
# CLOSE_GLD ::  111.45    > 143.6691  =>   False
# CLOSE_LIT ::  79.94     > 111.7797  =>   False
# CLOSE_LUNA ::  54.62     > 83.9383   =>   False
# CLOSE_NVO ::  36.62     > 60.0627   =>   False
# CLOSE_OIL ::  22.3      > 40.1749   =>   False
# CLOSE_VTI ::  12.84     > 24.2761   =>   False
# CLOSE_CGW ::  5.84      > 12.3212   =>   False
# CLOSE_ZEC ::  1.34      > 4.1296    =>   False
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/vector_ar/vecm.py:608: HypothesisTestWarning: Critical values are only available for time series with 12 variables at most.
#   category=HypothesisTestWarning)

# %% [markdown]
# Given non of the series is cointegrated, we must take the 1st difference:

# %%
data_close_select_ffill_diff = data_close_select_ffill.diff().dropna()

# %%
cointegration_test(data_close_select_ffill_diff)
# Out:
# Name   ::  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# CLOSE_BLK ::  2198.02   > nan       =>   False
# CLOSE_DBA ::  1907.97   > 311.1288  =>   True
# CLOSE_BTC ::  1666.62   > 263.2603  =>   True
# CLOSE_ETH ::  1451.02   > 219.4051  =>   True
# CLOSE_EWS ::  1244.02   > 179.5199  =>   True
# CLOSE_GLD ::  1060.17   > 143.6691  =>   True
# CLOSE_LIT ::  896.34    > 111.7797  =>   True
# CLOSE_LUNA ::  739.65    > 83.9383   =>   True
# CLOSE_NVO ::  592.95    > 60.0627   =>   True
# CLOSE_OIL ::  455.59    > 40.1749   =>   True
# CLOSE_VTI ::  326.04    > 24.2761   =>   True
# CLOSE_CGW ::  205.41    > 12.3212   =>   True
# CLOSE_ZEC ::  94.02     > 4.1296    =>   True
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/vector_ar/vecm.py:608: HypothesisTestWarning: Critical values are only available for time series with 12 variables at most.
#   category=HypothesisTestWarning)

# %%
data_close_select_ffill_diff.head()
# Out:
#             CLOSE_BLK  CLOSE_DBA   CLOSE_BTC  ...  CLOSE_VTI  CLOSE_CGW  CLOSE_ZEC
# Date                                          ...
# 2019-08-12  -9.318146  -0.511960 -140.962891  ...  -1.766510  -0.124233  -3.162701
# 2019-08-13   8.375946  -0.049226 -486.786133  ...   2.016159   0.286682  -1.510811
# 2019-08-14 -13.152771   0.029535 -844.125977  ...  -4.137955  -0.850487  -4.888126
# 2019-08-15  -1.950348  -0.078762  259.841797  ...   0.259232   0.315350   0.437977
# 2019-08-16   9.572571  -0.049228   62.792969  ...   2.112152   0.363132  -1.901680
#
# [5 rows x 13 columns]

# %%
cointegration_test(data_log_returns_select_ffill)
# Out:
# Name   ::  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# LOG_RETURN_BLK ::  1944.7    > nan       =>   False
# LOG_RETURN_DBA ::  1708.33   > 311.1288  =>   True
# LOG_RETURN_BTC ::  1484.35   > 263.2603  =>   True
# LOG_RETURN_ETH ::  1290.34   > 219.4051  =>   True
# LOG_RETURN_EWS ::  1110.62   > 179.5199  =>   True
# LOG_RETURN_GLD ::  946.42    > 143.6691  =>   True
# LOG_RETURN_LIT ::  784.22    > 111.7797  =>   True
# LOG_RETURN_LUNA ::  637.73    > 83.9383   =>   True
# LOG_RETURN_NVO ::  495.31    > 60.0627   =>   True
# LOG_RETURN_OIL ::  374.2     > 40.1749   =>   True
# LOG_RETURN_VTI ::  259.76    > 24.2761   =>   True
# LOG_RETURN_CGW ::  162.24    > 12.3212   =>   True
# LOG_RETURN_ZEC ::  75.85     > 4.1296    =>   True
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/vector_ar/vecm.py:608: HypothesisTestWarning: Critical values are only available for time series with 12 variables at most.
#   category=HypothesisTestWarning)

# %% [markdown]
# #### Training and Testing Data

# %% [markdown]
# Splitting the dataset into training and test data. The VAR model will be fitted on df_train and then used to forecast the next 30 observations. These forecasts will be compared against the actuals present in test data. To do the comparisons, we will use multiple forecast accuracy metrics, as seen later in this article.

# %%
nobs = 30
df_close_train_og, df_close_test_og = data_close_select_ffill[0:-nobs], data_close_select_ffill[-nobs:]
df_close_train, df_close_test = data_close_select_ffill_diff[0:-nobs], data_close_select_ffill_diff[-nobs:]

# Check size
print(df_close_train.shape)  # (119, 8)
print(df_close_test.shape)  # (4, 8)
# Out:
# (880, 13)
# (30, 13)

# %% [markdown]
# #### Make Time Series Stationary

# %% [markdown]
# Since the VAR model requires the time series you want to forecast to be stationary, it is customary to check all the time series in the system for stationarity. Just to refresh, a stationary time series is one whose characteristics like mean and variance does not change over time. So, how to test for stationarity? There is a suite of tests called unit-root tests. The popular ones are:
#
# 1. Augmented Dickey-Fuller Test (ADF Test)
#
# 2. KPSS test
#
# 3. Philip-Perron test.
#
#  Let’s use the ADF test for our purpose. By the way, if a series is found to be non-stationary, you make it stationary by differencing the series once and repeat the test again until it becomes stationary. Since, differencing reduces the length of the series by 1 and since all the time series has to be of the same length, you need to difference all the series in the system if you choose to difference at all.
#
# Got it? Let’s implement the ADF Test. First, we implement a nice function (`adfuller_test()`) that writes out the results of the ADF test for any given time series and implement this function on each series one-by-one.

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
# ADF Test on each column
for name, column in df_close_train.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "CLOSE_BLK"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.9774
#  No. Lags Chosen       = 10
#  Critical value 1%     = -3.438
#  Critical value 5%     = -2.865
#  Critical value 10%    = -2.569
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CLOSE_DBA"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -28.1877
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.438
#  Critical value 5%     = -2.865
#  Critical value 10%    = -2.569
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CLOSE_BTC"
#     -----------------------------------------------
# ...

# %% [markdown]
# We can confirm that after taking one difference, all of our time series are stationary, so we can proceed.

# %% [markdown]
# #### Order $p$ of VAR Model

# %% [markdown]
# To select the right order of the VAR model, we iteratively fit increasing orders of VAR model and pick the order that gives a model with least AIC.
#
# Though the usual practice is to look at the AIC, you can also check other best fit comparison estimates of BIC, FPE and HQIC.

# %%
model = VAR(df_close_train)
for i in [1,2,3,4,5,6,7,8,9]:
    result = model.fit(i)
    print('Lag Order =', i)
    print('AIC : ', result.aic)
    print('BIC : ', result.bic)
    print('FPE : ', result.fpe)
    print('HQIC: ', result.hqic, '\n')
# Out:
# Lag Order = 1
# AIC :  22.547673390919254
# BIC :  23.537137385661808
# FPE :  6199338392.98822
# HQIC:  22.92608342923862
#
# Lag Order = 2
# AIC :  22.648216833387124
# BIC :  24.558187168655834
# FPE :  6856541595.040367
# HQIC:  23.37870454636191
#
# Lag Order = 3
# AIC :  22.78539029032938
# BIC :  25.617526705418932
# FPE :  7869132179.892619
# HQIC:  23.868628884836312
#
# Lag Order = 4
# AIC :  22.907827934926786
# BIC :  26.663795100058266
# FPE :  8903867501.047396
# HQIC:  24.3444926682564
#
# Lag Order = 5
# AIC :  23.01831387348337
# BIC :  27.699781410048892
# FPE :  9962022091.681488
# HQIC:  24.809082061870555
#
# Lag Order = 6
# AIC :  23.10929055019028
# BIC :  28.717933051103593
# FPE :  10940336484.26434
# HQIC:  25.25484157738977
#
# Lag Order = 7
# AIC :  23.127389222991916
# BIC :  29.664886273145598
# FPE :  11182327888.324524
# HQIC:  25.628404548899013
#
# Lag Order = 8
# AIC :  23.26667678507998
# BIC :  30.734712981909976
# FPE :  12918689508.267134
# ...

# %% [markdown]
# In the above output, the AIC drops to lowest at lag 1, then increases and keeps on doing so. Let’s go with the lag 1 model.
#
# An alternate method to choose the order(p) of the VAR models is to use the model.select_order(maxlags) method. The selected order(p) is the order that gives the lowest ‘AIC’, ‘BIC’, ‘FPE’ and ‘HQIC’ scores.

# %%
x = model.select_order(maxlags=12)
x.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# #### Train the VAR Model of Selected Order(p)

# %%
model_fitted = model.fit(1)
model_fitted.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 06, Feb, 2022
# Time:                     07:23:45
# --------------------------------------------------------------------
# No. of Equations:         13.0000    BIC:                    23.5371
# Nobs:                     879.000    HQIC:                   22.9261
# Log likelihood:          -25941.9    FPE:                6.19934e+09
# AIC:                      22.5477    Det(Omega_mle):     5.04814e+09
# --------------------------------------------------------------------
# Results for equation CLOSE_BLK
# ...
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.596995         0.327228            1.824           0.068
# L1.CLOSE_BLK         -0.009764         0.056253           -0.174           0.862
# ...

# %% [markdown]
# #### Check for Serial Correlation of Residuals (Errors) using Durbin Watson Statistic

# %% [markdown]
# Serial correlation of residuals is used to check if there is any leftover pattern in the residuals (errors). What does this mean to us? If there is any correlation left in the residuals, then, there is some pattern in the time series that is still left to be explained by the model.
#
#
# In that case, the typical course of action is to either increase the order of the model or induce more predictors into the system or look for a different algorithm to model the time series. So, checking for serial correlation is to ensure that the model is sufficiently able to explain the variances and patterns in the time series.
#
# Alright, coming back to topic. A common way of checking for serial correlation of errors can be measured using the Durbin Watson’s Statistic:
#
# $$DW = \frac{\Sigma^{T}_{t=2}(e_{t}-e_{t-1})^{2}}{\Sigma^{T}_{t=1}e^{2}_{t}}$$

# %% [markdown]
# The value of this statistic can vary between 0 and 4. The closer it is to the value 2, then there is no significant serial correlation. The closer to 0, there is a positive serial correlation, and the closer it is to 4 implies negative serial correlation.

# %%
from statsmodels.stats.stattools import durbin_watson

def adjust(val, length= 6): return str(val).ljust(length)
out = durbin_watson(model_fitted.resid)

for col, val in zip(df_close_train.columns, out):
    print(adjust(col), ':', round(val, 2))
# Out:
# CLOSE_BLK : 2.0
# CLOSE_DBA : 2.0
# CLOSE_BTC : 1.99
# CLOSE_ETH : 1.95
# CLOSE_EWS : 2.0
# CLOSE_GLD : 1.99
# CLOSE_LIT : 2.02
# CLOSE_LUNA : 1.97
# CLOSE_NVO : 2.0
# CLOSE_OIL : 2.13
# CLOSE_VTI : 1.99
# CLOSE_CGW : 2.0
# CLOSE_ZEC : 1.96

# %% [markdown]
# The serial correlation seems quite alright. Let’s proceed with the forecast.

# %% [markdown]
# #### Forecast VAR Model using statsmodels

# %% [markdown]
# In order to forecast, the VAR model expects up to the lag order number of observations from the past data. This is because, the terms in the VAR model are essentially the lags of the various time series in the dataset, so you need to provide it as many of the previous values as indicated by the lag order used by the model.

# %%
# Get the lag order
lag_order = model_fitted.k_ar
print(lag_order)  #> 4

# Input data for forecasting
forecast_input = df_close_train.values[-lag_order:]
forecast_input
# Out:
# 1
# array([[-3.21997070e+00,  1.70000076e-01, -1.60302734e+03,
#         -2.25197754e+02,  1.80000305e-01,  7.59994507e-01,
#         -6.00051880e-02, -9.76956177e+00, -1.37000275e+00,
#         -5.59997559e-01, -1.08000183e+00, -2.29999542e-01,
#          1.43580627e+00]])

# %%
# Forecast
fc = model_fitted.forecast(y=forecast_input, steps=nobs)
df_forecast = pd.DataFrame(fc, index=data_close_select_ffill_diff.index[-nobs:], columns=data_close_select_ffill_diff.columns + '_1d')
df_forecast
# Out:
#             CLOSE_BLK_1d  CLOSE_DBA_1d  ...  CLOSE_CGW_1d  CLOSE_ZEC_1d
# Date                                    ...
# 2022-01-08     -0.552150      0.002352  ...      0.052510     -2.958383
# 2022-01-09      0.152426      0.006677  ...      0.010136      0.382184
# 2022-01-10      0.625060      0.006010  ...      0.026510      0.034331
# 2022-01-11      0.544076      0.005524  ...      0.025848      0.096704
# 2022-01-12      0.568204      0.005530  ...      0.026186      0.087222
# 2022-01-13      0.564312      0.005542  ...      0.026312      0.091371
# 2022-01-14      0.564730      0.005544  ...      0.026212      0.089840
# 2022-01-15      0.564735      0.005542  ...      0.026258      0.090396
# 2022-01-16      0.564698      0.005543  ...      0.026239      0.090186
# 2022-01-17      0.564721      0.005543  ...      0.026246      0.090265
# 2022-01-18      0.564711      0.005543  ...      0.026244      0.090236
# ...

# %% [markdown]
# The forecasts are generated but it is on the scale of the training data used by the model. So, to bring it back up to its original scale, you need to de-difference it as many times you had differenced the original input data.

# %% [markdown]
# #### Invert the transformation to get the real forecast

# %%
def invert_transformation(df_train, df_forecast, second_diff=False):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back 2nd Diff
        if second_diff:
            df_fc[str(col)+'_1d'] = (df_train[col].iloc[-1]-df_train[col].iloc[-2]) + df_fc[str(col)+'_2d'].cumsum()
            
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = df_train[col].iloc[-1] + df_fc[str(col)+'_1d'].cumsum()
    return df_fc

# %%
df_results = invert_transformation(df_close_train_og, df_forecast, second_diff=False)

# %%
df_results
# Out:
#             CLOSE_BLK_1d  CLOSE_DBA_1d  ...  CLOSE_CGW_forecast  CLOSE_ZEC_forecast
# Date                                    ...
# 2022-01-08     -0.552150      0.002352  ...           58.302510          136.630164
# 2022-01-09      0.152426      0.006677  ...           58.312646          137.012347
# 2022-01-10      0.625060      0.006010  ...           58.339157          137.046678
# 2022-01-11      0.544076      0.005524  ...           58.365005          137.143382
# 2022-01-12      0.568204      0.005530  ...           58.391190          137.230604
# 2022-01-13      0.564312      0.005542  ...           58.417502          137.321976
# 2022-01-14      0.564730      0.005544  ...           58.443715          137.411815
# 2022-01-15      0.564735      0.005542  ...           58.469972          137.502212
# 2022-01-16      0.564698      0.005543  ...           58.496211          137.592398
# 2022-01-17      0.564721      0.005543  ...           58.522458          137.682663
# ...

# %% [markdown]
# #### Plot Forecasts vs. Actuals

# %%
fig, axes = plt.subplots(nrows=int(len(df_close_train_og.columns)/2), ncols=2, dpi=150, figsize=(10,10))

for i, (col,ax) in enumerate(zip(df_close_train_og.columns, axes.flatten())):
    df_results[col+'_forecast'].plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    df_close_test_og[col][-nobs:].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %% [markdown]
# #### Evaluate the Forecasts

# %% [markdown]
# To evaluate the forecasts, let’s compute a comprehensive set of metrics, namely, the MAPE, ME, MAE, MPE, RMSE, corr and minmax.

# %%
from statsmodels.tsa.stattools import acf

def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'corr':corr, 'minmax':minmax})

# %%
df_results_fc = df_results.iloc[:, -13:]

# %%
df_results_fc.columns
# Out:
# Index(['CLOSE_BLK_forecast', 'CLOSE_DBA_forecast', 'CLOSE_BTC_forecast',
#        'CLOSE_ETH_forecast', 'CLOSE_EWS_forecast', 'CLOSE_GLD_forecast',
#        'CLOSE_LIT_forecast', 'CLOSE_LUNA_forecast', 'CLOSE_NVO_forecast',
#        'CLOSE_OIL_forecast', 'CLOSE_VTI_forecast', 'CLOSE_CGW_forecast',
#        'CLOSE_ZEC_forecast'],
#       dtype='object')

# %%
print('Forecast Accuracy of: BLK')
accuracy_prod = forecast_accuracy(df_results_fc['CLOSE_BLK_forecast'].values, df_close_test_og['CLOSE_BLK'])
for k, v in accuracy_prod.items():
    print(adjust(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: BLK
# mape   :  0.0865
# me     :  70.2208
# mae    :  70.2843
# mpe    :  0.0864
# rmse   :  78.8532
# corr   :  -0.783
# minmax :  0.078
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]

# %%
print('Forecast Accuracy of: DBA')
accuracy_prod = forecast_accuracy(df_results_fc['CLOSE_DBA_forecast'].values, df_close_test_og['CLOSE_DBA'])
for k, v in accuracy_prod.items():
    print(adjust(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: DBA
# mape   :  0.0113
# me     :  -0.1981
# mae    :  0.2304
# mpe    :  -0.0097
# rmse   :  0.2922
# corr   :  0.8943
# minmax :  0.0113
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]

# %%
print('Forecast Accuracy of: BTC')
accuracy_prod = forecast_accuracy(df_results_fc['CLOSE_BTC_forecast'].values, df_close_test_og['CLOSE_BTC'])
for k, v in accuracy_prod.items():
    print(adjust(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: BTC
# mape   :  0.0735
# me     :  2004.6161
# mae    :  2785.0949
# mpe    :  0.0553
# rmse   :  3472.3765
# corr   :  -0.537
# minmax :  0.066
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]

# %%
print('Forecast Accuracy of: ETH')
accuracy_prod = forecast_accuracy(df_results_fc['CLOSE_ETH_forecast'].values, df_close_test_og['CLOSE_ETH'])
for k, v in accuracy_prod.items():
    print(adjust(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: ETH
# mape   :  0.1457
# me     :  334.5762
# mae    :  382.8982
# mpe    :  0.1311
# rmse   :  478.7295
# corr   :  -0.5747
# minmax :  0.1182
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]

# %%
print('Forecast Accuracy of: EWS')
accuracy_prod = forecast_accuracy(df_results_fc['CLOSE_EWS_forecast'].values, df_close_test_og['CLOSE_EWS'])
for k, v in accuracy_prod.items():
    print(adjust(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: EWS
# mape   :  0.011
# me     :  -0.021
# mae    :  0.2337
# mpe    :  -0.0008
# rmse   :  0.2926
# corr   :  -0.3744
# minmax :  0.0109
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]

# %%
print('Forecast Accuracy of: GLD')
accuracy_prod = forecast_accuracy(df_results_fc['CLOSE_GLD_forecast'].values, df_close_test_og['CLOSE_GLD'])
for k, v in accuracy_prod.items():
    print(adjust(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: GLD
# mape   :  0.0115
# me     :  -1.8025
# mae    :  1.9609
# mpe    :  -0.0106
# rmse   :  2.4285
# corr   :  -0.2518
# minmax :  0.0115
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]

# %%
print('Forecast Accuracy of: LIT')
accuracy_prod = forecast_accuracy(df_results_fc['CLOSE_LIT_forecast'].values, df_close_test_og['CLOSE_LIT'])
for k, v in accuracy_prod.items():
    print(adjust(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: LIT
# mape   :  0.0426
# me     :  2.4047
# mae    :  3.3221
# mpe    :  0.0316
# rmse   :  3.9704
# corr   :  -0.6958
# minmax :  0.0403
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]

# %%
print('Forecast Accuracy of: LUNA')
accuracy_prod = forecast_accuracy(df_results_fc['CLOSE_LUNA_forecast'].values, df_close_test_og['CLOSE_LUNA'])
for k, v in accuracy_prod.items():
    print(adjust(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: LUNA
# mape   :  0.1998
# me     :  3.5817
# mae    :  11.9745
# mpe    :  0.0965
# rmse   :  13.6313
# corr   :  -0.8047
# minmax :  0.1629
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]

# %%
print('Forecast Accuracy of: NVO')
accuracy_prod = forecast_accuracy(df_results_fc['CLOSE_NVO_forecast'].values, df_close_test_og['CLOSE_NVO'])
for k, v in accuracy_prod.items():
    print(adjust(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: NVO
# mape   :  0.0428
# me     :  3.6323
# mae    :  4.1358
# mpe    :  0.038
# rmse   :  4.81
# corr   :  0.0862
# minmax :  0.0405
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]

# %%
print('Forecast Accuracy of: OIL')
accuracy_prod = forecast_accuracy(df_results_fc['CLOSE_OIL_forecast'].values, df_close_test_og['CLOSE_OIL'])
for k, v in accuracy_prod.items():
    print(adjust(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: OIL
# mape   :  0.0716
# me     :  -6.1828
# mae    :  6.2521
# mpe    :  -0.0707
# rmse   :  7.0536
# corr   :  0.9222
# minmax :  0.0716
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]

# %%
print('Forecast Accuracy of: VTI')
accuracy_prod = forecast_accuracy(df_results_fc['CLOSE_VTI_forecast'].values, df_close_test_og['CLOSE_VTI'])
for k, v in accuracy_prod.items():
    print(adjust(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: VTI
# mape   :  0.0457
# me     :  10.018
# mae    :  10.2181
# mpe    :  0.0449
# rmse   :  12.3176
# corr   :  -0.6716
# minmax :  0.0429
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]

# %%
print('Forecast Accuracy of: CGW')
accuracy_prod = forecast_accuracy(df_results_fc['CLOSE_CGW_forecast'].values, df_close_test_og['CLOSE_CGW'])
for k, v in accuracy_prod.items():
    print(adjust(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: CGW
# mape   :  0.0729
# me     :  3.9177
# mae    :  3.9177
# mpe    :  0.0729
# rmse   :  4.4124
# corr   :  -0.8997
# minmax :  0.0667
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]

# %%
print('Forecast Accuracy of: ZEC')
accuracy_prod = forecast_accuracy(df_results_fc['CLOSE_ZEC_forecast'].values, df_close_test_og['CLOSE_ZEC'])
for k, v in accuracy_prod.items():
    print(adjust(k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: ZEC
# mape   :  0.2587
# me     :  22.174
# mae    :  25.7232
# mpe    :  0.2339
# rmse   :  31.3839
# corr   :  -0.7531
# minmax :  0.1851
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   del sys.path[0]

# %% [markdown]
# #### FORECASTING (PENDING))

# %%
# forecasting
lag_order_2 = model_fitted.k_ar
results2 = model_fitted.forecast(data_close_select_ffill.values[-lag_order_2:], 15)

# %%
# Get the lag order
lag_order = model_fitted.k_ar
print(lag_order)  #> 4

# Input data for forecasting
forecast_input = data_close_select_ffill.values[-lag_order:]
forecast_input
# Forecast
fc2 = model_fitted.forecast(y=forecast_input, steps=nobs)
df_forecast_2 = pd.DataFrame(fc2, index=data_close_select_ffill_diff.index[-nobs:], columns=data_close_select_ffill_diff.columns + '_1d')
df_forecast_2
# Out:
# 1
#             CLOSE_BLK_1d  CLOSE_DBA_1d  ...  CLOSE_CGW_1d  CLOSE_ZEC_1d
# Date                                    ...
# 2022-01-08    -43.840542      1.241051  ...     -2.515990    -27.076676
# 2022-01-09     18.528283     -0.036745  ...      0.831761      3.530668
# 2022-01-10     -2.547163      0.006821  ...     -0.047916      0.431436
# 2022-01-11      1.357411      0.004926  ...      0.031856     -0.131531
# 2022-01-12      0.406883      0.005825  ...      0.030610      0.218831
# 2022-01-13      0.586994      0.005563  ...      0.022933      0.036376
# 2022-01-14      0.563676      0.005508  ...      0.027800      0.110530
# 2022-01-15      0.563582      0.005559  ...      0.025606      0.082692
# 2022-01-16      0.565481      0.005536  ...      0.026493      0.093034
# 2022-01-17      0.564355      0.005545  ...      0.026151      0.089223
# 2022-01-18      0.564861      0.005542  ...      0.026279      0.090615
# ...

# %%
results2.plot_forecast()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-63cfbdf96e86> in <module>()
# ----> 1 results2.plot_forecast()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot_forecast'

# %%
results2
# Out:
# array([[-4.38405420e+01,  1.24105105e+00, -3.70874008e+03,
#         -7.40129913e+02, -5.69263968e-01,  2.85032391e+01,
#         -2.36892108e+00, -1.05794975e+01, -3.05207991e-01,
#         -1.22408858e+01, -1.56891307e+01, -2.51598985e+00,
#         -2.70766759e+01],
#        [ 1.85282828e+01, -3.67453581e-02,  1.66428755e+02,
#         -4.05569078e+01,  2.25920950e-01,  1.00212602e+00,
#          1.22914553e+00, -1.35041313e-01, -4.11070974e-01,
#          5.40718044e+00,  4.37634127e+00,  8.31760999e-01,
#          3.53066765e+00],
#        [-2.54716350e+00,  6.82086751e-03,  1.42344145e+02,
#          1.60944693e+01,  7.06804849e-03,  1.41543217e-01,
#          7.37548276e-02,  1.08904380e-01, -8.13005255e-02,
#         -2.12410310e+00, -3.96467892e-01, -4.79155922e-02,
#          4.31436196e-01],
#        [ 1.35741077e+00,  4.92649951e-03,  2.11457631e+01,
#          2.42660972e+00, -5.05689249e-03, -8.31640557e-02,
#          5.34904394e-02,  1.15350230e-01,  1.05962847e-01,
# ...
